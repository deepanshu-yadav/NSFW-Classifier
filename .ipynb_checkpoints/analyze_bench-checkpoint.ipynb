# %% [markdown]
# <h1> For conversion of .out files from batch transform to a csv file

# %%
#make_results_csv( 'bench_results' , '' , 'results_bench.csv'  , 'benchmark_images' )
# !pygmentize useful_scripts/useful_scripts/csv_maker.py
# Out:
# import os
# import csv
# import re
# import numpy as np
#
# def give_prediction_label(result_string):
#     #x = re.match("[(.*)]", result_string)
#     x = result_string[result_string.find('[')+1 : result_string.find(']')].split(',')
#     x_float = [ float(xi) for xi in x ]
#     ind = x_float.index(max(x_float))
#
#     return ind
#
#
#
# def make_results_csv( results_directory , csv_path , csv_file_name  , eval_image_path ):
#     with open(os.path.join(csv_path , csv_file_name), mode='w') as file:
#         writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#         writer.writerow(['Image_path', 'ground_truth_label', 'Predicted'])
#         i = 0
#         sorted_list = sorted(os.listdir(results_directory))
#         for single_class in sorted_list:
#             list_of_files = os.listdir(os.path.join( results_directory , single_class ))
#             for img_result in list_of_files:
#                 result_file = open(  os.path.join( results_directory , single_class , img_result )  , 'r')
#                 result_string = result_file.read()
#                 prediction_val = give_prediction_label(result_string)
#                 #print(result_string.split(','))
#                 label = str(i)
#                 img_path = os.path.join( eval_image_path , single_class ,img_result[:-4] )
#                 writer.writerow([img_path, label , prediction_val  ])
#                 result_file.close()
#             #print(i)
#             i += 1
# #make_results_csv('analyze/analyze' , 'dump' , 'results.csv' , 'nsfw_dataset_test' )

# %% [markdown]
# # This notebook is for  evaluating the results obtained after the batch transform was applied to the dataset obtained from [benchmark](https://towardsdatascience.com/comparison-of-the-best-nsfw-image-moderation-apis-2018-84be8da65303) .

# %%
import pandas as pd
df = pd.read_csv('results_bench.csv')

# %%
df.head()
# Out:
#                          Image_path  ground_truth_label  Predicted
# 0  benchmark_images/animated/11.jpg                   0          0
# 1  benchmark_images/animated/12.jpg                   0          0
# 2  benchmark_images/animated/14.jpg                   0          0
# 3   benchmark_images/animated/3.jpg                   0          2
# 4   benchmark_images/animated/6.jpg                   0          0

# %% [markdown]
# <h1>Preparation of Confusion Matrix

# %%
comparison = df.iloc[:, [1,2]].values

# %%
import numpy as np
samples = comparison.shape[0]
conf_matrix = np.zeros( (5, 5) , dtype=np.int32 )

for i in range(samples):
    conf_matrix[ int(comparison[i][0]) ][ int(comparison[i][1])  ] += 1

print(conf_matrix)
# Out:
# [[12  0  3  0  0]
#  [ 0  1  9  0  4]
#  [ 0  1  7  0  4]
#  [ 3  2  3  0 12]
#  [ 0  1  2  0 15]]

# %% [markdown]
# <h1> Confusion Matrix Plot

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df_cm = pd.DataFrame(conf_matrix, index = ['animated_ori' , 'nude_ori' , 'porn_ori' , 'safe for work_ori' , 'semi_nude_ori'],
                  columns = ['animated_pred' , 'nude_pred' , 'porn_pred' , 'safe for work_pred' , 'semi_nude_pred'])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)

# %% [markdown]
# <h1> Wrong Examples cant show it you (you know why )

# %%
wrong_examples = df[df['ground_truth_label'] != df['Predicted']].sample(n=9)

# %%
# from IPython.display import Image
# from IPython.display import display



# for i in range(9):
#     x= Image(wrong_examples.iloc[i,0])
#     display(x)

# ;

# %% [markdown]
# <h1>Function That Calculates metrics for a single class

# %% [markdown]
# <h2> notice class names are in alphabetic order

# %%
def get_metrics_for_single_class(class_label, conf_matrix):
    tn = 0
    for i in range(5):
        for j in range(5):
            if i != class_label or j != class_label:
                tn += conf_matrix[i][j]


    tp = conf_matrix[class_label][class_label]

    fp = np.sum(conf_matrix[class_label][:]  ) - conf_matrix[class_label][class_label] 
    fn =  np.sum(conf_matrix[:][class_label] ) -conf_matrix[class_label][class_label]

    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1_score = (precision*recall)/ (precision+recall)
    
    return accuracy , precision , recall , f1_score

# %% [markdown]
# <h1> Metrics for class Animated

# %%
acc , pre , rec , f1 = get_metrics_for_single_class(0,conf_matrix)
print(acc ,pre, rec , f1)
# Out:
# 0.9294117647058824 0.8 0.8 0.4000000000000001

# %% [markdown]
# <h1> Metrics for class Nude

# %%
acc , pre , rec , f1 = get_metrics_for_single_class(1,conf_matrix)
print(acc ,pre, rec , f1)
# Out:
# 0.7523809523809524 0.07142857142857142 0.07142857142857142 0.03571428571428571

# %% [markdown]
# <h1> Metrics for class Porn

# %%
acc , pre , rec , f1 = get_metrics_for_single_class(2,conf_matrix)
print(acc ,pre, rec , f1)
# Out:
# 0.8876404494382022 0.5833333333333334 0.5833333333333334 0.2916666666666667

# %% [markdown]
# <h1> Metrics for class Safe for work

# %%
acc , pre , rec , f1 = get_metrics_for_single_class(3,conf_matrix)
print(acc ,pre, rec , f1)
# Out:
# 0.6638655462184874 0.0 0.0 nan
# /home/deepanshu/Documents/udacity_project_plagarism/workspace_udacity/lib/python3.5/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# <h1> Metrics for class Semi Nude

# %%
acc , pre , rec , f1 = get_metrics_for_single_class(4,conf_matrix)
print(acc ,pre, rec , f1)
# Out:
# 0.9294117647058824 0.8333333333333334 0.8333333333333334 0.4166666666666667

# %% [markdown]
# <h1>Metrics for all 4 nsfw classes

# %%
def get_metrics_for_nsfw():
    safe_for_work_label = 3
    tp = 0
    for i in range(5):
        for j in range(5):
            if i != safe_for_work_label or j != safe_for_work_label:
                tp += conf_matrix[i][j]


    tn = conf_matrix[3][3]

    fn = conf_matrix[3][0] + conf_matrix[3][1]  + conf_matrix[3][2] + conf_matrix[3][4]  
    fp = conf_matrix[2][3] + conf_matrix[1][3]  + conf_matrix[0][3] + conf_matrix[4][3] 

    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    f1_score = (precision*recall)/ (precision+recall)
    return accuracy , precision , recall , f1_score

# %%
acc , pre , rec , f1 = get_metrics_for_nsfw()
print(acc ,pre, rec , f1)
# Out:
# 0.797979797979798 1.0 0.797979797979798 0.44382022471910115

# %% [markdown]
# **As from the examples above we can see my model performs poorly for safe for work . Or is it  that poor.
#     Lets find out by plotting wrong images classified for safe for work.**

# %%
safe_images = df[df['ground_truth_label'] == 3].values

def getname(ind):
    if ind == 0:
        return 'animated'
    elif ind == 1:
        return 'Nude'
    if ind == 2:
        return 'Porn'
    if ind == 3:
        return 'Safe For Work'
    if ind == 4:
        return 'Semi Nude'

from IPython.display import Image
from IPython.display import display



for i in range(safe_images.shape[0]):
    x= Image(safe_images[i][0])
    display(x)
    print('predicted is %s original was %s' %( getname(safe_images[i][2]) , getname(safe_images[i][1]) ) )
# Out:
# predicted is Porn original was Safe For Work
# predicted is animated original was Safe For Work
# predicted is Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is animated original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is animated original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Porn original was Safe For Work
# predicted is Porn original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work
# predicted is Semi Nude original was Safe For Work

# %% [markdown]
# **No doubt the model fails to say safe for really safe iamges but in some cases it actually does a good job i had put beach wear and belly exposed type of images in semi -nude category during preparation of dataset**
